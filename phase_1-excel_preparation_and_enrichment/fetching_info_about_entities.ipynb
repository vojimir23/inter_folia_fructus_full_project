# %%
import openpyxl
import requests
import os
import time

def get_wikidata_info(wikidata_id):
    """
    Safely fetches specified information from Wikidata for a given Wikidata ID.
    Returns a dictionary with the information, or None if the ID is invalid or an error occurs.
    """
    # Basic validation of the Wikidata ID format
    if not (isinstance(wikidata_id, str) and wikidata_id.startswith('Q') and wikidata_id[1:].isdigit()):
        print(f"  - Invalid Wikidata ID format: '{wikidata_id}'. Skipping.")
        return None

    url = 'https://www.wikidata.org/w/api.php'
    params = {
        'action': 'wbgetentities',
        'ids': wikidata_id,
        'format': 'json',
        'props': 'descriptions|aliases|claims'
    }

    try:
        response = requests.get(url, params=params, headers={'User-Agent': 'MyCoolTool/1.0'})
        response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)
        data = response.json()

        # Check if the entity exists in the response
        entity = data.get('entities', {}).get(wikidata_id)
        if not entity or 'missing' in entity:
            print(f"  - Could not find data for Wikidata ID: {wikidata_id}")
            return None

        info = {
            'DESCRIPTION_WIKIDATA': '',
            'ALSO_KNOWN_AS': '',
            'VIAF_CODE': '',
            'WIKIDATA_ID': wikidata_id,
            'COORDINATES': ''
        }

        #  SAFE DATA EXTRACTION 
        # Get description (safer using .get())
        info['DESCRIPTION_WIKIDATA'] = entity.get('descriptions', {}).get('en', {}).get('value', '')

        # Get "also known as" and join with semicolon
        aliases_en = entity.get('aliases', {}).get('en', [])
        if aliases_en:
            info['ALSO_KNOWN_AS'] = '; '.join([alias.get('value', '') for alias in aliases_en])

        # Get claims (VIAF code P214 and Coordinates P625)
        claims = entity.get('claims', {})
        
        # Get all VIAF codes (P214) and join with semicolon
        viaf_claims = claims.get('P214', [])
        if viaf_claims:
            viaf_codes = [claim.get('mainsnak', {}).get('datavalue', {}).get('value', '') for claim in viaf_claims]
            info['VIAF_CODE'] = '; '.join(filter(None, viaf_codes))

        # Get Coordinates (P625) only if they exist, and format them cleanly
        coords_claim = claims.get('P625', [])
        if coords_claim:
            coords_value = coords_claim[0].get('mainsnak', {}).get('datavalue', {}).get('value', {})
            lat = coords_value.get('latitude')
            lon = coords_value.get('longitude')
            if lat is not None and lon is not None:
                info['COORDINATES'] = f"{lat}, {lon}"
        
        return info

    except requests.exceptions.RequestException as e:
        print(f"  - An error occurred while fetching data for {wikidata_id}: {e}")
        return None
    except Exception as e:
        print(f"  - An unexpected error occurred while processing {wikidata_id}: {e}")
        return None

def process_excel_file(file_path):
    """
    Opens an XLSX file, scrapes data from Wikidata for specific worksheets,
    and saves the updated data back to the same file.
    """
    print(f"IMPORTANT: Please ensure the file '{os.path.basename(file_path)}' is closed to avoid errors.")

    try:
        workbook = openpyxl.load_workbook(file_path)
    except Exception as e:
        print(f"Error opening the Excel file: {e}. Is the file open in another program?")
        return

    #  1) PROCESS ONLY SPECIFIC WORKSHEETS 
    target_sheets = ['PLACE', 'PERSON', 'ABSTRACT_CHARACTER', 'EVENT', 'INSTITUTION']

    for sheet_name in target_sheets:
        if sheet_name not in workbook.sheetnames:
            print(f"\nWorksheet '{sheet_name}' not found in this file. Skipping.")
            continue

        worksheet = workbook[sheet_name]
        entity_name = sheet_name
        print(f"\nProcessing worksheet: '{sheet_name}'...")

        wikidata_link_col_name = f"WIKIDATA_LINK_{entity_name}"
        
        header = [cell.value for cell in worksheet[1]]
        
        try:
            wikidata_link_col_idx = header.index(wikidata_link_col_name) + 1
        except ValueError:
            print(f"  - Column '{wikidata_link_col_name}' not found. Skipping this sheet.")
            continue

        #  2) CONDITIONALLY DEFINE HEADERS (COORDINATES FOR PLACE/EVENT ONLY) 
        base_headers = ['DESCRIPTION_WIKIDATA', 'ALSO_KNOWN_AS', 'VIAF_CODE', 'WIKIDATA_ID']
        if entity_name in ['PLACE', 'EVENT']:
            base_headers.append('COORDINATES')
        
        #  3) DYNAMICALLY CREATE NEW HEADERS WITH SUFFIX 
        new_headers = [f"{h}_{entity_name}" for h in base_headers]
        
        col_map = {}
        
        # Find existing columns or determine the next available column
        last_col = worksheet.max_column
        for col_name in new_headers:
            if col_name in header:
                col_map[col_name] = header.index(col_name) + 1
            else:
                last_col += 1
                worksheet.cell(row=1, column=last_col, value=col_name)
                col_map[col_name] = last_col
        
        print(f"  - Data will be written to columns (Header: Index): {col_map}")

        # Process each row
        for row_idx in range(2, worksheet.max_row + 1):
            wikidata_url = worksheet.cell(row=row_idx, column=wikidata_link_col_idx).value
            
            if wikidata_url and isinstance(wikidata_url, str):
                wikidata_id = wikidata_url.split('/')[-1]
                print(f"  - Row {row_idx}: Processing Wikidata ID '{wikidata_id}'...")
                
                scraped_data = get_wikidata_info(wikidata_id)
                
                if scraped_data:
                    # Populate the data into the correct, dynamically named columns
                    worksheet.cell(row=row_idx, column=col_map[f'DESCRIPTION_WIKIDATA_{entity_name}'], value=scraped_data['DESCRIPTION_WIKIDATA'])
                    worksheet.cell(row=row_idx, column=col_map[f'ALSO_KNOWN_AS_{entity_name}'], value=scraped_data['ALSO_KNOWN_AS'])
                    worksheet.cell(row=row_idx, column=col_map[f'VIAF_CODE_{entity_name}'], value=scraped_data['VIAF_CODE'])
                    worksheet.cell(row=row_idx, column=col_map[f'WIKIDATA_ID_{entity_name}'], value=scraped_data['WIKIDATA_ID'])
                    
                    # Conditionally populate coordinates
                    if entity_name in ['PLACE', 'EVENT']:
                        worksheet.cell(row=row_idx, column=col_map[f'COORDINATES_{entity_name}'], value=scraped_data['COORDINATES'])
                
                # Be polite to the API and wait a little
                time.sleep(0.1) 
            else:
                print(f"  - Row {row_idx}: No Wikidata URL found. Skipping.")

    try:
        workbook.save(file_path)
        print(f"\n--- Successfully saved the updated data to '{file_path}' ---")
    except Exception as e:
        print(f"\nCRITICAL ERROR: Could not save the Excel file: {e}")
        print("Please ensure the file is not open elsewhere and you have permission to write to that location.")

if __name__ == '__main__':
    #  AUTOMATICALLY FIND AND PROCESS ALL XLSX FILES IN THE SCRIPT'S DIRECTORY 
    script_directory = os.getcwd()
    print(f"Searching for .xlsx files in: {script_directory}")
    
    excel_files = [f for f in os.listdir(script_directory) if f.endswith('.xlsx')]

    if not excel_files:
        print("No .xlsx files found in the script's directory.")
    else:
        print(f"Found files: {excel_files}")
        for file_name in excel_files:
            # Make sure not to process temporary excel files created when a file is open
            if file_name.startswith('~$'):
                continue
            
            file_path = os.path.join(script_directory, file_name)
            print(f"\n=========================================")
            print(f"Processing file: {file_name}")
            print(f"=========================================")
            process_excel_file(file_path)
    
    print("\nAll files processed.")
# Out:
# Searching for .xlsx files in: c:\Users\vojim\Desktop\ERA_IFF_FINAL\phase_1-excel_preparation_and_enrichment
# Found files: ['BA-EG.xlsx', 'BPC-AB.xlsx', 'columns_trace.xlsx']
#
# =========================================
# Processing file: BA-EG.xlsx
# =========================================
# IMPORTANT: Please ensure the file 'BA-EG.xlsx' is closed to avoid errors.
#
# Processing worksheet: 'PLACE'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_PLACE': 4, 'ALSO_KNOWN_AS_PLACE': 5, 'VIAF_CODE_PLACE': 6, 'WIKIDATA_ID_PLACE': 8, 'COORDINATES_PLACE': 9}
#   - Row 2: No Wikidata URL found. Skipping.
#   - Row 3: Processing Wikidata ID 'Q89804530'...
#   - Row 4: Processing Wikidata ID 'Q64'...
#   - Row 5: Processing Wikidata ID 'Q23725'...
#   - Row 6: Processing Wikidata ID 'Q2044'...
#   - Row 7: Processing Wikidata ID 'Q20050'...
#   - Row 8: Processing Wikidata ID 'Q71'...
#   - Row 9: Processing Wikidata ID 'Q1055'...
#   - Row 10: Processing Wikidata ID 'Q41'...
#   - Row 11: Processing Wikidata ID 'Q38'...
#   - Row 12: Processing Wikidata ID 'Q2079'...
#   - Row 13: Processing Wikidata ID 'Q84'...
#   - Row 14: Processing Wikidata ID 'Q490'...
#   - Row 15: Processing Wikidata ID 'Q34217'...
#   - Row 16: Processing Wikidata ID 'Q90'...
#   - Row 17: Processing Wikidata ID 'Q220'...
#   - Row 18: Processing Wikidata ID 'Q20489'...
#   - Row 19: Processing Wikidata ID 'Q22638'...
#   - Row 20: No Wikidata URL found. Skipping.
#   - Row 21: Processing Wikidata ID 'Q641'...
#   - Row 22: Processing Wikidata ID 'Q6537'...
#   - Row 23: Processing Wikidata ID 'Q3033'...
#   - Row 24: Processing Wikidata ID 'Q1345'...
#   - Row 25: Processing Wikidata ID 'Q6221'...
#
# Processing worksheet: 'PERSON'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_PERSON': 12, 'ALSO_KNOWN_AS_PERSON': 13, 'VIAF_CODE_PERSON': 14, 'WIKIDATA_ID_PERSON': 16}
#   - Row 2: Processing Wikidata ID 'Q112398799'...
#   - Row 3: Processing Wikidata ID 'Q346052'...
#   - Row 4: Processing Wikidata ID 'Q380793'...
#   - Row 5: Processing Wikidata ID 'Q43423'...
#   - Row 6: Processing Wikidata ID 'Q233136'...
#   - Row 7: Processing Wikidata ID 'Q1754523'...
#   - Row 8: Processing Wikidata ID 'Q317146'...
#   - Row 9: Processing Wikidata ID 'Q695923'...
#   - Row 10: Processing Wikidata ID 'Q123147'...
#   - Row 11: No Wikidata URL found. Skipping.
#   - Row 12: No Wikidata URL found. Skipping.
#   - Row 13: No Wikidata URL found. Skipping.
#   - Row 14: No Wikidata URL found. Skipping.
#   - Row 15: No Wikidata URL found. Skipping.
#   - Row 16: No Wikidata URL found. Skipping.
#   - Row 17: No Wikidata URL found. Skipping.
#   - Row 18: No Wikidata URL found. Skipping.
#   - Row 19: No Wikidata URL found. Skipping.
#   - Row 20: No Wikidata URL found. Skipping.
#   - Row 21: No Wikidata URL found. Skipping.
#   - Row 22: No Wikidata URL found. Skipping.
#   - Row 23: No Wikidata URL found. Skipping.
#   - Row 24: No Wikidata URL found. Skipping.
#   - Row 25: No Wikidata URL found. Skipping.
#   - Row 26: No Wikidata URL found. Skipping.
#   - Row 27: No Wikidata URL found. Skipping.
#   - Row 28: No Wikidata URL found. Skipping.
#   - Row 29: No Wikidata URL found. Skipping.
#   - Row 30: No Wikidata URL found. Skipping.
#   - Row 31: No Wikidata URL found. Skipping.
#   - Row 32: No Wikidata URL found. Skipping.
#   - Row 33: No Wikidata URL found. Skipping.
#   - Row 34: No Wikidata URL found. Skipping.
#   - Row 35: No Wikidata URL found. Skipping.
#   - Row 36: No Wikidata URL found. Skipping.
#   - Row 37: No Wikidata URL found. Skipping.
#   - Row 38: No Wikidata URL found. Skipping.
#   - Row 39: No Wikidata URL found. Skipping.
#   - Row 40: No Wikidata URL found. Skipping.
#   - Row 41: No Wikidata URL found. Skipping.
#   - Row 42: No Wikidata URL found. Skipping.
#   - Row 43: No Wikidata URL found. Skipping.
#   - Row 44: No Wikidata URL found. Skipping.
#   - Row 45: No Wikidata URL found. Skipping.
#   - Row 46: No Wikidata URL found. Skipping.
#   - Row 47: No Wikidata URL found. Skipping.
#   - Row 48: No Wikidata URL found. Skipping.
#   - Row 49: No Wikidata URL found. Skipping.
#   - Row 50: No Wikidata URL found. Skipping.
#   - Row 51: No Wikidata URL found. Skipping.
#   - Row 52: No Wikidata URL found. Skipping.
#   - Row 53: No Wikidata URL found. Skipping.
#   - Row 54: Processing Wikidata ID 'Q192638'...
#   - Row 55: Processing Wikidata ID 'Q43353'...
#   - Row 56: Processing Wikidata ID 'Q868'...
#   - Row 57: Processing Wikidata ID 'Q868'...
#   - Row 58: Processing Wikidata ID 'Q234593'...
#   - Row 59: Processing Wikidata ID 'Q451390'...
#   - Row 60: Processing Wikidata ID '88707151'...
#   - Invalid Wikidata ID format: '88707151'. Skipping.
#   - Row 61: Processing Wikidata ID 'Q3087726'...
#   - Row 62: Processing Wikidata ID 'Q77606'...
#   - Row 63: Processing Wikidata ID 'Q334188'...
#   - Row 64: Processing Wikidata ID 'Q113736325'...
#   - Row 65: Processing Wikidata ID 'Q3071870'...
#   - Row 66: Processing Wikidata ID '305291421'...
#   - Invalid Wikidata ID format: '305291421'. Skipping.
#   - Row 67: Processing Wikidata ID '250487039'...
#   - Invalid Wikidata ID format: '250487039'. Skipping.
#   - Row 68: Processing Wikidata ID 'Q105967796'...
#   - Row 69: Processing Wikidata ID 'Q4006391'...
#   - Row 70: Processing Wikidata ID 'Q87338672'...
#   - Row 71: Processing Wikidata ID 'Q109837010'...
#   - Row 72: Processing Wikidata ID 'Q469171'...
#   - Row 73: Processing Wikidata ID 'Q116571'...
#   - Row 74: Processing Wikidata ID 'Q15450375'...
#   - Row 75: Processing Wikidata ID 'Q1048'...
#   - Row 76: Processing Wikidata ID 'Q983661'...
#   - Row 77: Processing Wikidata ID 'Q16550450'...
#   - Row 78: Processing Wikidata ID 'Q3558630'...
#   - Row 79: Processing Wikidata ID 'Q192417'...
#   - Row 80: No Wikidata URL found. Skipping.
#   - Row 81: Processing Wikidata ID '311283150'...
#   - Invalid Wikidata ID format: '311283150'. Skipping.
#   - Row 82: Processing Wikidata ID 'Q3171225'...
#   - Row 83: Processing Wikidata ID 'Q1541'...
#   - Row 84: Processing Wikidata ID 'Q83159'...
#   - Row 85: Processing Wikidata ID 'Q214179'...
#   - Row 86: Processing Wikidata ID 'Q18527527'...
#   - Row 87: No Wikidata URL found. Skipping.
#   - Row 88: Processing Wikidata ID 'Q6216617'...
#   - Row 89: Processing Wikidata ID 'Q431336'...
#   - Row 90: Processing Wikidata ID 'Q1866952'...
#   - Row 91: Processing Wikidata ID 'Q171724'...
#   - Row 92: Processing Wikidata ID '9916896'...
#   - Invalid Wikidata ID format: '9916896'. Skipping.
#   - Row 93: Processing Wikidata ID '25670793'...
#   - Invalid Wikidata ID format: '25670793'. Skipping.
#   - Row 94: Processing Wikidata ID '46147663000460551486'...
#   - Invalid Wikidata ID format: '46147663000460551486'. Skipping.
#   - Row 95: Processing Wikidata ID 'Q2987520'...
#   - Row 96: Processing Wikidata ID 'Q55233197'...
#   - Row 97: No Wikidata URL found. Skipping.
#   - Row 98: Processing Wikidata ID 'Q1922172'...
#   - Row 99: Processing Wikidata ID 'Q297776'...
#   - Row 100: Processing Wikidata ID 'Q113784204'...
#   - Row 101: Processing Wikidata ID 'Q19408605'...
#   - Row 102: Processing Wikidata ID 'Q8747'...
#   - Row 103: Processing Wikidata ID 'Q343018'...
#   - Row 104: Processing Wikidata ID 'Q48305'...
#   - Row 105: Processing Wikidata ID 'Q453465'...
#   - Row 106: Processing Wikidata ID 'Q3561265'...
#   - Row 107: Processing Wikidata ID 'Q61894'...
#   - Row 108: Processing Wikidata ID 'Q3741767'...
#   - Row 109: Processing Wikidata ID 'Q60843485'...
#   - Row 110: Processing Wikidata ID 'Q3475912'...
#   - Row 111: Processing Wikidata ID 'Q2424118'...
#   - Row 112: Processing Wikidata ID 'Q8778'...
#   - Row 113: Processing Wikidata ID 'Q114352868'...
#   - Row 114: Processing Wikidata ID 'Q104156041'...
#   - Row 115: Processing Wikidata ID 'Q287485'...
#   - Row 116: Processing Wikidata ID 'Q294800'...
#   - Row 117: No Wikidata URL found. Skipping.
#   - Row 118: Processing Wikidata ID 'Q428139'...
#   - Row 119: Processing Wikidata ID '225421348'...
#   - Invalid Wikidata ID format: '225421348'. Skipping.
#   - Row 120: Processing Wikidata ID '66611339'...
#   - Invalid Wikidata ID format: '66611339'. Skipping.
#   - Row 121: Processing Wikidata ID 'Q345506'...
#   - Row 122: Processing Wikidata ID 'Q59627253'...
#   - Row 123: Processing Wikidata ID 'Q721412'...
#   - Row 124: Processing Wikidata ID 'Q3732053'...
#   - Row 125: Processing Wikidata ID 'Q380826'...
#   - Row 126: Processing Wikidata ID 'Q44233'...
#   - Row 127: Processing Wikidata ID 'Q94868093'...
#   - Row 128: Processing Wikidata ID 'Q5264'...
#   - Row 129: Processing Wikidata ID 'Q21545644'...
#   - Row 130: Processing Wikidata ID 'Q6691'...
#   - Row 131: Processing Wikidata ID 'Q16853945'...
#   - Row 132: Processing Wikidata ID '7742038'...
#   - Invalid Wikidata ID format: '7742038'. Skipping.
#   - Row 133: Processing Wikidata ID 'Q3154779'...
#   - Row 134: Processing Wikidata ID 'Q221182'...
#   - Row 135: Processing Wikidata ID 'Q548104'...
#   - Row 136: Processing Wikidata ID 'Q7996'...
#   - Row 137: Processing Wikidata ID 'Q498547'...
#   - Row 138: Processing Wikidata ID 'Q317632'...
#   - Row 139: Processing Wikidata ID '29574375'...
#   - Invalid Wikidata ID format: '29574375'. Skipping.
#   - Row 140: Processing Wikidata ID 'Q55908727'...
#   - Row 141: Processing Wikidata ID 'Q21543670'...
#   - Row 142: Processing Wikidata ID 'Q49237'...
#   - Row 143: Processing Wikidata ID 'Q59530741'...
#   - Row 144: Processing Wikidata ID 'Q3836871'...
#   - Row 145: Processing Wikidata ID 'Q177847'...
#   - Row 146: Processing Wikidata ID 'Q107557397'...
#   - Row 147: Processing Wikidata ID 'Q650448'...
#   - Row 148: Processing Wikidata ID 'Q213220'...
#   - Row 149: Processing Wikidata ID 'Q2459068'...
#   - Row 150: Processing Wikidata ID 'Q19514800'...
#   - Row 151: Processing Wikidata ID 'Q19514601'...
#   - Row 152: Processing Wikidata ID 'Q941151'...
#   - Row 153: Processing Wikidata ID '89291827'...
#   - Invalid Wikidata ID format: '89291827'. Skipping.
#   - Row 154: Processing Wikidata ID 'Q1398'...
#   - Row 155: Processing Wikidata ID 'Q105739137'...
#   - Row 156: Processing Wikidata ID 'BR1178'...
#   - Invalid Wikidata ID format: 'BR1178'. Skipping.
#   - Row 157: Processing Wikidata ID 'Q61477692'...
#   - Row 158: No Wikidata URL found. Skipping.
#   - Row 159: Processing Wikidata ID 'Q6835560'...
#   - Row 160: Processing Wikidata ID 'Q294109'...
#   - Row 161: Processing Wikidata ID 'Q4002845'...
#   - Row 162: Processing Wikidata ID 'Q650448'...
#   - Row 163: Processing Wikidata ID 'Q1242157'...
#   - Row 164: Processing Wikidata ID 'Q7198'...
#   - Row 165: Processing Wikidata ID '249956216'...
#   - Invalid Wikidata ID format: '249956216'. Skipping.
#   - Row 166: Processing Wikidata ID 'Q39489892'...
#   - Row 167: Processing Wikidata ID 'Q953784'...
#   - Row 168: Processing Wikidata ID 'Q2262449'...
#   - Row 169: Processing Wikidata ID 'Q580565'...
#   - Row 170: No Wikidata URL found. Skipping.
#   - Row 171: Processing Wikidata ID 'Q540679'...
#   - Row 172: Processing Wikidata ID 'Q112413257'...
#   - Row 173: Processing Wikidata ID 'Q1231472'...
#   - Row 174: Processing Wikidata ID 'Q349889'...
#   - Row 175: Processing Wikidata ID 'Q1338411'...
#   - Row 176: Processing Wikidata ID 'Q2090833'...
#   - Row 177: Processing Wikidata ID 'Q128019'...
#   - Row 178: Processing Wikidata ID 'Q218672'...
#   - Row 179: Processing Wikidata ID 'Q859'...
#   - Row 180: Processing Wikidata ID 'Q41523'...
#   - Row 181: No Wikidata URL found. Skipping.
#   - Row 182: Processing Wikidata ID 'Q203445'...
#   - Row 183: Processing Wikidata ID 'Q33978303'...
#   - Row 184: No Wikidata URL found. Skipping.
#   - Row 185: No Wikidata URL found. Skipping.
#   - Row 186: Processing Wikidata ID 'Q297402'...
#   - Row 187: Processing Wikidata ID 'Q193769'...
#   - Row 188: Processing Wikidata ID '33771482'...
#   - Invalid Wikidata ID format: '33771482'. Skipping.
#   - Row 189: Processing Wikidata ID 'Q52153970'...
#   - Row 190: Processing Wikidata ID 'Q110253155'...
#   - Row 191: Processing Wikidata ID 'Q2853443'...
#   - Row 192: Processing Wikidata ID 'Q43776600'...
#   - Row 193: Processing Wikidata ID 'Q113736789'...
#   - Row 194: Processing Wikidata ID 'cnp01239459'...
#   - Invalid Wikidata ID format: 'cnp01239459'. Skipping.
#   - Row 195: Processing Wikidata ID 'Q87190189'...
#   - Row 196: No Wikidata URL found. Skipping.
#   - Row 197: Processing Wikidata ID 'Q369313'...
#   - Row 198: Processing Wikidata ID 'Q103931'...
#   - Row 199: Processing Wikidata ID 'Q103931'...
#   - Row 200: Processing Wikidata ID '57983364'...
#   - Invalid Wikidata ID format: '57983364'. Skipping.
#   - Row 201: Processing Wikidata ID 'Q64533042'...
#   - Row 202: Processing Wikidata ID 'Q351518'...
#   - Row 203: Processing Wikidata ID 'Q1037347'...
#   - Row 204: Processing Wikidata ID '100219934'...
#   - Invalid Wikidata ID format: '100219934'. Skipping.
#   - Row 205: No Wikidata URL found. Skipping.
#   - Row 206: Processing Wikidata ID 'Q219484'...
#   - Row 207: Processing Wikidata ID 'Q317029'...
#   - Row 208: Processing Wikidata ID 'Q160362'...
#   - Row 209: Processing Wikidata ID 'Q2735899'...
#   - Row 210: Processing Wikidata ID 'Q41683'...
#   - Row 211: Processing Wikidata ID 'Q61482452'...
#   - Row 212: Processing Wikidata ID 'Q3616075'...
#   - Row 213: Processing Wikidata ID 'Q59529149'...
#   - Row 214: Processing Wikidata ID 'Q87766257'...
#   - Row 215: Processing Wikidata ID '265356044'...
#   - Invalid Wikidata ID format: '265356044'. Skipping.
#   - Row 216: Processing Wikidata ID 'Q3552244'...
#   - Row 217: Processing Wikidata ID 'Q61482654'...
#   - Row 218: Processing Wikidata ID 'Q104831643'...
#   - Row 219: Processing Wikidata ID 'Q110964675'...
#   - Row 220: Processing Wikidata ID 'Q59526869'...
#   - Row 221: Processing Wikidata ID 'Q741149'...
#   - Row 222: Processing Wikidata ID 'Q55136709'...
#   - Row 223: Processing Wikidata ID 'Q1041000'...
#   - Row 224: Processing Wikidata ID 'Q129772'...
#   - Row 225: Processing Wikidata ID 'Q317089'...
#   - Row 226: Processing Wikidata ID 'Q21548264'...
#   - Row 227: Processing Wikidata ID ''...
#   - Invalid Wikidata ID format: ''. Skipping.
#   - Row 228: No Wikidata URL found. Skipping.
#
# Processing worksheet: 'ABSTRACT_CHARACTER'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_ABSTRACT_CHARACTER': 8, 'ALSO_KNOWN_AS_ABSTRACT_CHARACTER': 9, 'VIAF_CODE_ABSTRACT_CHARACTER': 10, 'WIKIDATA_ID_ABSTRACT_CHARACTER': 12}
#   - Row 2: Processing Wikidata ID 'Q116437'...
#   - Row 3: Processing Wikidata ID 'Q193115'...
#   - Row 4: Processing Wikidata ID 'Q385397'...
#
# Processing worksheet: 'EVENT'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_EVENT': 7, 'ALSO_KNOWN_AS_EVENT': 8, 'VIAF_CODE_EVENT': 9, 'WIKIDATA_ID_EVENT': 11, 'COORDINATES_EVENT': 12}
#   - Row 2: No Wikidata URL found. Skipping.
#   - Row 3: Processing Wikidata ID 'Q160077'...
#   - Row 4: No Wikidata URL found. Skipping.
#
# Processing worksheet: 'INSTITUTION'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_INSTITUTION': 10, 'ALSO_KNOWN_AS_INSTITUTION': 11, 'VIAF_CODE_INSTITUTION': 12, 'WIKIDATA_ID_INSTITUTION': 14}
#   - Row 2: Processing Wikidata ID 'Q815611'...
#   - Row 3: Processing Wikidata ID 'E39QH7JmppHQrv4vH7JfQv9wRg'...
#   - Invalid Wikidata ID format: 'E39QH7JmppHQrv4vH7JfQv9wRg'. Skipping.
#   - Row 4: Processing Wikidata ID 'Q9592'...
#   - Row 5: Processing Wikidata ID 'Q3237899'...
#   - Row 6: No Wikidata URL found. Skipping.
#   - Row 7: Processing Wikidata ID 'Q795207'...
#   - Row 8: Processing Wikidata ID 'Q217595'...
#   - Row 9: Processing Wikidata ID '125314769'...
#   - Invalid Wikidata ID format: '125314769'. Skipping.
#   - Row 10: Processing Wikidata ID 'Q229022'...
#   - Row 11: Processing Wikidata ID '148644526'...
#   - Invalid Wikidata ID format: '148644526'. Skipping.
#   - Row 12: Processing Wikidata ID '2248145857086822921889'...
#   - Invalid Wikidata ID format: '2248145857086822921889'. Skipping.
#   - Row 13: Processing Wikidata ID '332159474180827661449'...
#   - Invalid Wikidata ID format: '332159474180827661449'. Skipping.
#   - Row 14: Processing Wikidata ID 'Q60431205'...
#   - Row 15: Processing Wikidata ID 'Q2901274'...
#   - Row 16: Processing Wikidata ID 'Q23308'...
#   - Row 17: Processing Wikidata ID 'Q2510139'...
#   - Row 18: Processing Wikidata ID '#Centro_nazionale_d'informazioni_bibliografiche_(Italy)'...
#   - Invalid Wikidata ID format: '#Centro_nazionale_d'informazioni_bibliografiche_(Italy)'. Skipping.
#   - Row 19: Processing Wikidata ID '#Libreria_dello_Stato_(Italy)'...
#   - Invalid Wikidata ID format: '#Libreria_dello_Stato_(Italy)'. Skipping.
#   - Row 20: Processing Wikidata ID 'Q6382871'...
#   - Row 21: Processing Wikidata ID 'Q81191'...
#   - Row 22: Processing Wikidata ID 'Q466089'...
#   - Row 23: Processing Wikidata ID 'Q55831605'...
#   - Row 24: Processing Wikidata ID 'Q45031506'...
#
# --- Successfully saved the updated data to 'c:\Users\vojim\Desktop\ERA_IFF_FINAL\phase_1-excel_preparation_and_enrichment\BA-EG.xlsx' ---
#
# =========================================
# Processing file: BPC-AB.xlsx
# =========================================
# IMPORTANT: Please ensure the file 'BPC-AB.xlsx' is closed to avoid errors.
#
# Processing worksheet: 'PLACE'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_PLACE': 4, 'ALSO_KNOWN_AS_PLACE': 5, 'VIAF_CODE_PLACE': 6, 'WIKIDATA_ID_PLACE': 8, 'COORDINATES_PLACE': 9}
#   - Row 2: Processing Wikidata ID 'Q490'...
#   - Row 3: Processing Wikidata ID 'Q641'...
#   - Row 4: Processing Wikidata ID 'Q90'...
#   - Row 5: Processing Wikidata ID 'Q15940034'...
#   - Row 6: Processing Wikidata ID 'Q71'...
#   - Row 7: Processing Wikidata ID 'Q63946'...
#   - Row 8: Processing Wikidata ID 'Q29'...
#   - Row 9: Processing Wikidata ID 'Q100'...
#   - Row 10: Processing Wikidata ID 'Q142'...
#   - Row 11: Processing Wikidata ID 'Q193785'...
#
# Processing worksheet: 'PERSON'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_PERSON': 12, 'ALSO_KNOWN_AS_PERSON': 13, 'VIAF_CODE_PERSON': 14, 'WIKIDATA_ID_PERSON': 16}
#   - Row 2: Processing Wikidata ID 'Q295830'...
#   - Row 3: Processing Wikidata ID 'Q687'...
#   - Row 4: Processing Wikidata ID 'E39PCjv6tvMMbG974p6Qk9wYMX'...
#   - Invalid Wikidata ID format: 'E39PCjv6tvMMbG974p6Qk9wYMX'. Skipping.
#   - Row 5: Processing Wikidata ID 'E39PCjqDH6DRgmk9TjJrRMCxpd'...
#   - Invalid Wikidata ID format: 'E39PCjqDH6DRgmk9TjJrRMCxpd'. Skipping.
#   - Row 6: Processing Wikidata ID 'E39PBJwD3KmhTvcD3b9F8dPYT3'...
#   - Invalid Wikidata ID format: 'E39PBJwD3KmhTvcD3b9F8dPYT3'. Skipping.
#   - Row 7: Processing Wikidata ID 'Q45898365'...
#   - Row 8: No Wikidata URL found. Skipping.
#   - Row 9: No Wikidata URL found. Skipping.
#   - Row 10: Processing Wikidata ID 'Q29109950'...
#   - Row 11: Processing Wikidata ID 'Q368470'...
#   - Row 12: Processing Wikidata ID 'Q22693448'...
#   - Row 13: Processing Wikidata ID 'E39PCjthkF6fJPRJ9wHB9fCmMK.html'...
#   - Invalid Wikidata ID format: 'E39PCjthkF6fJPRJ9wHB9fCmMK.html'. Skipping.
#   - Row 14: Processing Wikidata ID 'Q188794'...
#   - Row 15: Processing Wikidata ID 'Q42381999'...
#   - Row 16: Processing Wikidata ID 'Q3081769'...
#   - Row 17: Processing Wikidata ID 'Q381800'...
#   - Row 18: Processing Wikidata ID 'Q458390'...
#   - Row 19: Processing Wikidata ID 'Q22075474'...
#
# Processing worksheet: 'ABSTRACT_CHARACTER'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_ABSTRACT_CHARACTER': 8, 'ALSO_KNOWN_AS_ABSTRACT_CHARACTER': 9, 'VIAF_CODE_ABSTRACT_CHARACTER': 10, 'WIKIDATA_ID_ABSTRACT_CHARACTER': 12}
#   - Row 2: Processing Wikidata ID 'Scapin'...
#   - Invalid Wikidata ID format: 'Scapin'. Skipping.
#   - Row 3: No Wikidata URL found. Skipping.
#   - Row 4: No Wikidata URL found. Skipping.
#   - Row 5: No Wikidata URL found. Skipping.
#   - Row 6: No Wikidata URL found. Skipping.
#   - Row 7: No Wikidata URL found. Skipping.
#   - Row 8: Processing Wikidata ID 'Q190'...
#
# Processing worksheet: 'EVENT'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_EVENT': 7, 'ALSO_KNOWN_AS_EVENT': 8, 'VIAF_CODE_EVENT': 9, 'WIKIDATA_ID_EVENT': 11, 'COORDINATES_EVENT': 12}
#   - Row 2: Processing Wikidata ID 'Q162691'...
#   - Row 3: Processing Wikidata ID 'Q201201'...
#
# Processing worksheet: 'INSTITUTION'...
#   - Data will be written to columns (Header: Index): {'DESCRIPTION_WIKIDATA_INSTITUTION': 10, 'ALSO_KNOWN_AS_INSTITUTION': 11, 'VIAF_CODE_INSTITUTION': 12, 'WIKIDATA_ID_INSTITUTION': 14}
#   - Row 2: Processing Wikidata ID 'Q118347240'...
#   - Row 3: Processing Wikidata ID 'Q98045184'...
#   - Row 4: Processing Wikidata ID 'Q273835'...
#   - Row 5: Processing Wikidata ID 'Q78620888'...
#   - Row 6: Processing Wikidata ID 'Q273819'...
#   - Row 7: No Wikidata URL found. Skipping.
#   - Row 8: Processing Wikidata ID 'Q161806'...
#   - Row 9: No Wikidata URL found. Skipping.
#   - Row 10: Processing Wikidata ID 'Q17517389'...
#   - Row 11: Processing Wikidata ID 'Q390074'...
#
# --- Successfully saved the updated data to 'c:\Users\vojim\Desktop\ERA_IFF_FINAL\phase_1-excel_preparation_and_enrichment\BPC-AB.xlsx' ---
#
# =========================================
# Processing file: columns_trace.xlsx
# =========================================
# IMPORTANT: Please ensure the file 'columns_trace.xlsx' is closed to avoid errors.
#
# Worksheet 'PLACE' not found in this file. Skipping.
#
# Worksheet 'PERSON' not found in this file. Skipping.
#
# Worksheet 'ABSTRACT_CHARACTER' not found in this file. Skipping.
#
# Worksheet 'EVENT' not found in this file. Skipping.
#
# Worksheet 'INSTITUTION' not found in this file. Skipping.
#
# --- Successfully saved the updated data to 'c:\Users\vojim\Desktop\ERA_IFF_FINAL\phase_1-excel_preparation_and_enrichment\columns_trace.xlsx' ---
#
# All files processed.
