# %%
import pandas as pd
import os
from openpyxl import load_workbook

def update_excel_files_with_mentions_and_hypotheses():
    """
    This script processes all .xlsx files in the current directory to link mentions
    and hypotheses across different sheets, preserving original formatting.

    It performs the following steps:
    1.  Finds all non-temporary .xlsx files in the directory.
    2.  Concatenates the "MENTIONS" and "HYPOTHESIS" sheets from all
        found .xlsx files into single, master DataFrames.
    3.  Splits columns with multiple IDs (separated by ';') to handle multiple links
        from a single cell.
    4.  It then re-opens each workbook and for every sheet, it identifies a specific
        column that starts with the name '{sheet_name}_ID' (e.g., 'WORK_ID' for sheet 'WORK').
    5.  It then adds or updates three columns to these sheets:
        - '{sheet_name}_MENTIONING': Populated with 'MENTIONED_ID's.
        - '{sheet_name}_MENTIONED_BY': Populated with 'MENTIONING_ID's.
        - '{sheet_name}_HYPOTHESIS_ID': Populated with 'HYPOTHESIS_ID's.
    6.  The updated sheets are saved back to their original .xlsx files using
        openpyxl to preserve all existing cell formatting.
    """
    try:
        # Helper function for conditional lowercasing
        def custom_clean_and_format(s):
            if not isinstance(s, str):
                s = str(s)
            
            cleaned_parts = []
            for part in s.split(';'):
                stripped_part = part.strip()
                # Check for specific prefixes and preserve their case
                if stripped_part.startswith(('VO_', 'PAG_', 'PO_')):
                    cleaned_parts.append(stripped_part.replace(' ', '_'))
                else:
                    # Lowercase for everything else
                    cleaned_parts.append(stripped_part.lower().replace(' ', '_'))
            return ';'.join(cleaned_parts)

        # 1. Find all .xlsx files, ignoring temporary files
        xlsx_files = [f for f in os.listdir('.') if f.endswith('.xlsx') and not f.startswith('~')]

        if not xlsx_files:
            print("No .xlsx files were found in the current directory.")
            return

        # 2. Read and concatenate all "MENTIONS" and "HYPOTHESIS" sheets from all files
        print("Step 1: Consolidating all 'MENTIONS' and 'HYPOTHESIS' sheets...")
        mentions_dfs = []
        hypothesis_dfs = []
        for file in xlsx_files:
            try:
                xls = pd.ExcelFile(file)
                if 'MENTIONS' in xls.sheet_names:
                    df = pd.read_excel(file, sheet_name='MENTIONS')
                    mentions_dfs.append(df)
                    print(f"  - Found and read 'MENTIONS' from {file}")
                if 'HYPOTHESIS' in xls.sheet_names:
                    df = pd.read_excel(file, sheet_name='HYPOTHESIS')
                    hypothesis_dfs.append(df)
                    print(f"  - Found and read 'HYPOTHESIS' from {file}")
            except Exception as e:
                print(f"Warning: Could not read sheets from {file}: {e}")

        if not mentions_dfs and not hypothesis_dfs:
            print("No 'MENTIONS' or 'HYPOTHESIS' sheets were found. Stopping.")
            return

        # Process MENTIONS
        if mentions_dfs:
            master_mentions_df = pd.concat(mentions_dfs, ignore_index=True)
            print("Successfully consolidated all 'MENTIONS' sheets.")
            master_mentions_df.dropna(subset=['MENTIONING_ID', 'MENTIONED_ID'], inplace=True)
            for col in master_mentions_df.columns:
                master_mentions_df[col] = master_mentions_df[col].fillna('').astype(str).apply(custom_clean_and_format)
            
            master_mentions_df['MENTIONING_ID'] = master_mentions_df['MENTIONING_ID'].str.split(';')
            mentioning_exploded = master_mentions_df.explode('MENTIONING_ID')
            master_mentions_df['MENTIONED_ID'] = master_mentions_df['MENTIONED_ID'].str.split(';')
            mentioned_exploded = master_mentions_df.explode('MENTIONED_ID')
            
            mentioning_exploded['MENTIONING_ID'] = mentioning_exploded['MENTIONING_ID'].str.strip()
            mentioned_exploded['MENTIONED_ID'] = mentioned_exploded['MENTIONED_ID'].str.strip()
        else:
            master_mentions_df = pd.DataFrame()
            mentioning_exploded = pd.DataFrame(columns=['MENTIONING_ID', 'MENTIONED_ID'])
            mentioned_exploded = pd.DataFrame(columns=['MENTIONING_ID', 'MENTIONED_ID'])
            print("No 'MENTIONS' sheets found to process.")

        # Process HYPOTHESIS
        if hypothesis_dfs:
            master_hypothesis_df = pd.concat(hypothesis_dfs, ignore_index=True)
            print("Successfully consolidated all 'HYPOTHESIS' sheets.")
            master_hypothesis_df.dropna(subset=['HYPOTHESIS_ID', 'HYPOTHESIS_ABOUT_ID(S)'], inplace=True)
            for col in master_hypothesis_df.columns:
                master_hypothesis_df[col] = master_hypothesis_df[col].fillna('').astype(str).apply(custom_clean_and_format)

            master_hypothesis_df['HYPOTHESIS_ABOUT_ID(S)'] = master_hypothesis_df['HYPOTHESIS_ABOUT_ID(S)'].str.split(';')
            hypothesis_exploded = master_hypothesis_df.explode('HYPOTHESIS_ABOUT_ID(S)')
            hypothesis_exploded['HYPOTHESIS_ABOUT_ID(S)'] = hypothesis_exploded['HYPOTHESIS_ABOUT_ID(S)'].str.strip()
        else:
            master_hypothesis_df = pd.DataFrame()
            hypothesis_exploded = pd.DataFrame(columns=['HYPOTHESIS_ID', 'HYPOTHESIS_ABOUT_ID(S)'])
            print("No 'HYPOTHESIS' sheets found to process.")


        # 4 & 5. Process each file again to add new columns
        print("\nStep 2: Updating sheets in each file...")
        for file in xlsx_files:
            try:
                print(f"Processing {file}...")
                original_sheets = pd.read_excel(file, sheet_name=None)
                
                for sheet_name, sheet_df in original_sheets.items():
                    for col in sheet_df.columns:
                        if ('ID' in col.split('_') or col == "PLACE_OF_PUBLICATION_MANIFESTATION" or col == "HYPOTHESIS_ABOUT_ID(S)") and col != "EXTERNAL_ID_MANIFESTATION":
                            print(f"  - Cleaning column '{col}' in sheet '{sheet_name}'...")
                            sheet_df[col] = sheet_df[col].fillna('').astype(str).apply(custom_clean_and_format)
                    
                    # 1) Clean the 'RELATIONSHIP' column in the 'RELATIONSHIP' sheet
                    if sheet_name == 'RELATIONSHIP' and 'RELATIONSHIP' in sheet_df.columns:
                        print("  - Cleaning column 'RELATIONSHIP' in sheet 'RELATIONSHIP'...")
                        sheet_df['RELATIONSHIP'] = sheet_df['RELATIONSHIP'].fillna('').astype(str).apply(
                            lambda s: s.strip().lower().replace(' ', '_')
                        )

                    original_sheets[sheet_name] = sheet_df

                workbook = load_workbook(file)

                for sheet_name in workbook.sheetnames:
                    worksheet = workbook[sheet_name]
                    sheet_df = original_sheets[sheet_name]

                    header_map = {cell.value: cell.column for cell in worksheet[1]}
                    for col_name in sheet_df.columns:
                        if 'ID' in col_name.split('_') or col_name == "PLACE_OF_PUBLICATION_MANIFESTATION" or col_name == "HYPOTHESIS_ABOUT_ID(S)" or (sheet_name == 'RELATIONSHIP' and col_name == 'RELATIONSHIP'):
                            if col_name in header_map:
                                col_idx = header_map[col_name]
                                print(f"  - Writing cleaned data back to column '{col_name}' in sheet '{sheet_name}'...")
                                cleaned_column_data = sheet_df[col_name]
                                for i, value in enumerate(cleaned_column_data, start=2):
                                    worksheet.cell(row=i, column=col_idx, value=value)

                    id_col_prefix = f"{sheet_name}_ID"
                    matching_id_cols = [col for col in sheet_df.columns if col.startswith(id_col_prefix)]
                    
                    id_col_to_use = None
                    if len(matching_id_cols) == 1:
                        id_col_to_use = matching_id_cols[0]
                        print(f"  - Found primary ID column for linking: '{id_col_to_use}'")
                    elif len(matching_id_cols) == 0:
                        print(f"  - Skipping sheet '{sheet_name}': No column found starting with '{id_col_prefix}'.")
                        continue
                    else:
                        print(f"  - Skipping sheet '{sheet_name}': Ambiguous ID columns found: {matching_id_cols}.")
                        continue
                    
                    print(f"  - Updating sheet '{sheet_name}' with links...")
                    
                    mentioning_col_name = f"{sheet_name}_MENTIONING"
                    mentioned_by_col_name = f"{sheet_name}_MENTIONED_BY"
                    hypothesis_col_name = f"{sheet_name}_HYPOTHESIS_ID"
                    
                    mentioning_values = []
                    mentioned_by_values = []
                    hypothesis_values = []

                    for index, row in sheet_df.iterrows():
                        cell_id = row[id_col_to_use]

                        # Process for MENTIONING
                        all_mentioned_ids = set()
                        if cell_id and cell_id != 'nan' and not mentioning_exploded.empty:
                            matched_mentions = mentioning_exploded[mentioning_exploded['MENTIONING_ID'] == cell_id]
                            for _, mention_row in matched_mentions.iterrows():
                                ids = mention_row['MENTIONED_ID']
                                if isinstance(ids, list):
                                    all_mentioned_ids.update(id.strip() for id in ids)
                                else:
                                    all_mentioned_ids.add(str(ids).strip())
                        mentioning_values.append(';'.join(sorted(list(all_mentioned_ids))))

                        # Process for MENTIONED_BY
                        all_mentioning_ids = set()
                        if cell_id and cell_id != 'nan' and not mentioned_exploded.empty:
                            matched_mentioned = mentioned_exploded[mentioned_exploded['MENTIONED_ID'] == cell_id]
                            for _, mention_row in matched_mentioned.iterrows():
                                ids = mention_row['MENTIONING_ID']
                                if isinstance(ids, list):
                                    all_mentioning_ids.update(id.strip() for id in ids)
                                else:
                                    all_mentioning_ids.add(str(ids).strip())
                        mentioned_by_values.append(';'.join(sorted(list(all_mentioning_ids))))

                        # Process for HYPOTHESIS
                        all_hypothesis_ids = set()
                        if cell_id and cell_id != 'nan' and not hypothesis_exploded.empty:
                            matched_hypothesis = hypothesis_exploded[hypothesis_exploded['HYPOTHESIS_ABOUT_ID(S)'] == cell_id]
                            for _, hypothesis_row in matched_hypothesis.iterrows():
                                all_hypothesis_ids.add(str(hypothesis_row['HYPOTHESIS_ID']).strip())
                        
                        # New functionality for MANIFESTATION sheet to also check MANIFESTATION_VOLUME_ID for hypotheses
                        if sheet_name == "MANIFESTATION" and "MANIFESTATION_VOLUME_ID" in sheet_df.columns:
                            volume_id = row["MANIFESTATION_VOLUME_ID"]
                            if volume_id and volume_id != 'nan' and not hypothesis_exploded.empty:
                                print(f"    - Also checking 'MANIFESTATION_VOLUME_ID': {volume_id} for hypotheses...")
                                matched_hypothesis_vol = hypothesis_exploded[hypothesis_exploded['HYPOTHESIS_ABOUT_ID(S)'] == volume_id]
                                for _, hypothesis_row in matched_hypothesis_vol.iterrows():
                                    all_hypothesis_ids.add(str(hypothesis_row['HYPOTHESIS_ID']).strip())

                        hypothesis_values.append(';'.join(sorted(list(all_hypothesis_ids))))

                    # New functionality for MANIFESTATION sheet
                    if sheet_name == "MANIFESTATION" and "MANIFESTATION_VOLUME_ID" in sheet_df.columns:
                        print("  - Processing 'MANIFESTATION_VOLUME_ID' for mentions...")
                        vol_mentioning_col_name = "MANIFESTATION_VOLUME_MENTIONING"
                        vol_mentioned_by_col_name = "MANIFESTATION_VOLUME_MENTIONED_BY"
                        
                        vol_mentioning_values = []
                        vol_mentioned_by_values = []

                        for index, row in sheet_df.iterrows():
                            volume_id = row["MANIFESTATION_VOLUME_ID"]

                            # Process for MENTIONING
                            all_mentioned_ids_vol = set()
                            if volume_id and volume_id != 'nan' and not mentioning_exploded.empty:
                                matched_mentions_vol = mentioning_exploded[mentioning_exploded['MENTIONING_ID'] == volume_id]
                                for _, mention_row in matched_mentions_vol.iterrows():
                                    ids = mention_row['MENTIONED_ID']
                                    if isinstance(ids, list):
                                        all_mentioned_ids_vol.update(id.strip() for id in ids)
                                    else:
                                        all_mentioned_ids_vol.add(str(ids).strip())
                            vol_mentioning_values.append(';'.join(sorted(list(all_mentioned_ids_vol))))

                            # Process for MENTIONED_BY
                            all_mentioning_ids_vol = set()
                            if volume_id and volume_id != 'nan' and not mentioned_exploded.empty:
                                matched_mentioned_vol = mentioned_exploded[mentioned_exploded['MENTIONED_ID'] == volume_id]
                                for _, mention_row in matched_mentioned_vol.iterrows():
                                    ids = mention_row['MENTIONING_ID']
                                    if isinstance(ids, list):
                                        all_mentioning_ids_vol.update(id.strip() for id in ids)
                                    else:
                                        all_mentioning_ids_vol.add(str(ids).strip())
                            vol_mentioned_by_values.append(';'.join(sorted(list(all_mentioning_ids_vol))))
                        
                        # Write MANIFESTATION_VOLUME mentions
                        current_header_map = {cell.value: cell.column for cell in worksheet[1] if cell.value}
                        if vol_mentioning_col_name in current_header_map:
                            vol_mentioning_col_idx = current_header_map[vol_mentioning_col_name]
                            print(f"  - Found existing column '{vol_mentioning_col_name}'. It will be updated.")
                        else:
                            vol_mentioning_col_idx = worksheet.max_column + 1
                            worksheet.cell(row=1, column=vol_mentioning_col_idx, value=vol_mentioning_col_name)
                            print(f"  - Creating new column '{vol_mentioning_col_name}'.")

                        if vol_mentioned_by_col_name in current_header_map:
                            vol_mentioned_by_col_idx = current_header_map[vol_mentioned_by_col_name]
                            print(f"  - Found existing column '{vol_mentioned_by_col_name}'. It will be updated.")
                        else:
                            vol_mentioned_by_col_idx = worksheet.max_column + 1
                            worksheet.cell(row=1, column=vol_mentioned_by_col_idx, value=vol_mentioned_by_col_name)
                            print(f"  - Creating new column '{vol_mentioned_by_col_name}'.")

                        for i, (mentioning_val, mentioned_by_val) in enumerate(zip(vol_mentioning_values, vol_mentioned_by_values)):
                            excel_row = i + 2
                            worksheet.cell(row=excel_row, column=vol_mentioning_col_idx, value=mentioning_val)
                            worksheet.cell(row=excel_row, column=vol_mentioned_by_col_idx, value=mentioned_by_val)


                    # 6. Use openpyxl to write new data
                    current_header_map = {cell.value: cell.column for cell in worksheet[1] if cell.value}

                    # Determine column for MENTIONING
                    if mentioning_col_name in current_header_map:
                        mentioning_col_idx = current_header_map[mentioning_col_name]
                        print(f"  - Found existing column '{mentioning_col_name}'. It will be updated.")
                    else:
                        mentioning_col_idx = worksheet.max_column + 1
                        worksheet.cell(row=1, column=mentioning_col_idx, value=mentioning_col_name)
                        print(f"  - Creating new column '{mentioning_col_name}'.")

                    # Determine column for MENTIONED_BY
                    if mentioned_by_col_name in current_header_map:
                        mentioned_by_col_idx = current_header_map[mentioned_by_col_name]
                        print(f"  - Found existing column '{mentioned_by_col_name}'. It will be updated.")
                    else:
                        mentioned_by_col_idx = worksheet.max_column + 1
                        worksheet.cell(row=1, column=mentioned_by_col_idx, value=mentioned_by_col_name)
                        print(f"  - Creating new column '{mentioned_by_col_name}'.")
                        
                    # Write the data for mentions
                    for i, (mentioning_val, mentioned_by_val) in enumerate(zip(mentioning_values, mentioned_by_values)):
                        excel_row = i + 2
                        worksheet.cell(row=excel_row, column=mentioning_col_idx, value=mentioning_val)
                        worksheet.cell(row=excel_row, column=mentioned_by_col_idx, value=mentioned_by_val)

                    # Determine and write column for HYPOTHESIS_ID, but NOT on the HYPOTHESIS sheet itself
                    if sheet_name != 'HYPOTHESIS':
                        if hypothesis_col_name in current_header_map:
                            hypothesis_col_idx = current_header_map[hypothesis_col_name]
                            print(f"  - Found existing column '{hypothesis_col_name}'. It will be updated.")
                        else:
                            hypothesis_col_idx = worksheet.max_column + 1
                            worksheet.cell(row=1, column=hypothesis_col_idx, value=hypothesis_col_name)
                            print(f"  - Creating new column '{hypothesis_col_name}'.")
                        
                        for i, hypothesis_val in enumerate(hypothesis_values):
                            excel_row = i + 2
                            worksheet.cell(row=excel_row, column=hypothesis_col_idx, value=hypothesis_val)


                if file.lower() != 'columns_trace.xlsx':
                    workbook.save(file)
                    print(f"Successfully saved updates to {file}\n")
                else:
                    print(f"Skipping save for '{file}' as per exclusion rules.\n")


            except Exception as e:
                print(f"An error occurred while processing {file}: {e}\n")

    except Exception as e:
        print(f"An unexpected critical error occurred: {e}")

if __name__ == "__main__":
    update_excel_files_with_mentions_and_hypotheses()
# Out:
# Step 1: Consolidating all 'MENTIONS' and 'HYPOTHESIS' sheets...
#   - Found and read 'MENTIONS' from BA-EG.xlsx
#   - Found and read 'HYPOTHESIS' from BA-EG.xlsx
#   - Found and read 'MENTIONS' from BPC-AB.xlsx
#   - Found and read 'HYPOTHESIS' from BPC-AB.xlsx
# Successfully consolidated all 'MENTIONS' sheets.
# Successfully consolidated all 'HYPOTHESIS' sheets.
#
# Step 2: Updating sheets in each file...
# Processing BA-EG.xlsx...
# C:\Users\vojim\AppData\Local\Temp\ipykernel_21340\732715385.py:94: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   master_hypothesis_df = pd.concat(hypothesis_dfs, ignore_index=True)
#   - Cleaning column 'WORK_ID' in sheet 'WORK'...
#   - Cleaning column 'AUTHOR_WORK_ID' in sheet 'WORK'...
#   - Cleaning column 'EXPRESSION_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'WORK_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'TRANSLATOR_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'EDITOR_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'SCRIPTWRITER_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'COMPOSITOR_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'REVIEWER_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'OTHER_SECONDARY_ROLE_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'MANIFESTATION_VOLUME_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'PLACE_OF_PUBLICATION_MANIFESTATION' in sheet 'MANIFESTATION'...
#   - Cleaning column 'EXPRESSION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'PUBLISHER_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'EDITOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'CORRECTOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'SPONSOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'ITEM_ID' in sheet 'ITEM'...
#   - Cleaning column 'OWNER_OF_ITEM_ID' in sheet 'ITEM'...
#   - Cleaning column 'MANIFESTATION_VOLUME_ID' in sheet 'ITEM'...
#   - Cleaning column 'MANIFESTATION_ID' in sheet 'ITEM'...
#   - Cleaning column 'PHYSICAL_OBJECT_ID' in sheet 'ITEM'...
#   - Cleaning column 'PLACE_ID' in sheet 'PLACE'...
#   - Cleaning column 'WIKIDATA_ID_PLACE' in sheet 'PLACE'...
#   - Cleaning column 'ITEM_ID' in sheet 'PAGE'...
#   - Cleaning column 'PHYSICAL_OBJECT_ID_PAGE' in sheet 'PAGE'...
#   - Cleaning column 'MANIFESTATION_ID' in sheet 'PAGE'...
#   - Cleaning column 'PAGE_ID' in sheet 'PAGE'...
#   - Cleaning column 'DIGITAL_ITEM_ID_PAGE' in sheet 'PAGE'...
#   - Cleaning column 'PHYSICAL_OBJECT_ID' in sheet 'PAGE'...
#   - Cleaning column 'VISUAL_OBJECT_ID' in sheet 'PAGE'...
#   - Cleaning column 'VISUAL_OBJECT_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'VO_ID_TEXT_REFERRED_TO' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'PLACE_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'OWNERSHIP_OF_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'INSCRIBER_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'SENDER_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'RECIPIENT_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'PERSON_ID' in sheet 'PERSON'...
#   - Cleaning column 'INSTITUTION_ID_OF_PERSON' in sheet 'PERSON'...
#   - Cleaning column 'WIKIDATA_ID_PERSON' in sheet 'PERSON'...
#   - Cleaning column 'PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Cleaning column 'PLACE_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Cleaning column 'OWNERSHIP_OF_PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Cleaning column 'CREATOR_OF_PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Cleaning column 'EVENT_ID' in sheet 'EVENT'...
#   - Cleaning column 'PLACE_ID' in sheet 'EVENT'...
#   - Cleaning column 'WIKIDATA_ID_EVENT' in sheet 'EVENT'...
#   - Cleaning column 'ABSTRACT_CHARACTER_ID' in sheet 'ABSTRACT_CHARACTER'...
#   - Cleaning column 'WIKIDATA_ID_ABSTRACT_CHARACTER' in sheet 'ABSTRACT_CHARACTER'...
#   - Cleaning column 'INSTITUTION_ID' in sheet 'INSTITUTION'...
#   - Cleaning column 'PLACE_ID' in sheet 'INSTITUTION'...
#   - Cleaning column 'WIKIDATA_ID_INSTITUTION' in sheet 'INSTITUTION'...
#   - Cleaning column 'MENTIONING_ID' in sheet 'MENTIONS'...
#   - Cleaning column 'MENTIONED_ID' in sheet 'MENTIONS'...
#   - Cleaning column 'PERSON_CHARACTER_ID_A' in sheet 'RELATIONSHIP'...
#   - Cleaning column 'PERSON_CHARACTER_ID_B' in sheet 'RELATIONSHIP'...
#   - Cleaning column 'RELATION_ID' in sheet 'RELATIONSHIP'...
#   - Cleaning column 'RELATIONSHIP' in sheet 'RELATIONSHIP'...
#   - Cleaning column 'HYPOTHESIS_ID' in sheet 'HYPOTHESIS'...
#   - Cleaning column 'PERSON_ID_HYPOTHESIS_OF' in sheet 'HYPOTHESIS'...
#   - Cleaning column 'HYPOTHESIS_ABOUT_ID(S)' in sheet 'HYPOTHESIS'...
#   - Writing cleaned data back to column 'WORK_ID' in sheet 'WORK'...
#   - Writing cleaned data back to column 'AUTHOR_WORK_ID' in sheet 'WORK'...
#   - Found primary ID column for linking: 'WORK_ID'
#   - Updating sheet 'WORK' with links...
#   - Creating new column 'WORK_MENTIONING'.
#   - Creating new column 'WORK_MENTIONED_BY'.
#   - Creating new column 'WORK_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'EXPRESSION_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'WORK_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'TRANSLATOR_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'EDITOR_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'SCRIPTWRITER_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'COMPOSITOR_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'REVIEWER_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'OTHER_SECONDARY_ROLE_ID' in sheet 'EXPRESSION'...
#   - Found primary ID column for linking: 'EXPRESSION_ID'
#   - Updating sheet 'EXPRESSION' with links...
#   - Creating new column 'EXPRESSION_MENTIONING'.
#   - Creating new column 'EXPRESSION_MENTIONED_BY'.
#   - Creating new column 'EXPRESSION_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'MANIFESTATION_VOLUME_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'EXTERNAL_ID_MANIFESTATION' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'PLACE_OF_PUBLICATION_MANIFESTATION' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'EXPRESSION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'PUBLISHER_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'EDITOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'CORRECTOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'SPONSOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Found primary ID column for linking: 'MANIFESTATION_ID'
#   - Updating sheet 'MANIFESTATION' with links...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1928_m_suidae_lexicon_leipzig_q2079_1928-1938 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_2/5_1931_m_suidae_lexicon_leipzig_q2079_1928-1938 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_3/5_1933_m_suidae_lexicon_leipzig_q2079_1928-1938 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_4/5_1935_m_suidae_lexicon_leipzig_q2079_1928-1938 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_4/5_1935_m_suidae_lexicon_leipzig_q2079_1928-1938 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_5/5_1938_m_suidae_lexicon_leipzig_q2079_1928-1938 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_47_2007_m_greek_roman_and_byzantine_studies_1959- for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_27/2_1953_m_aevum_1927- for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_96/3_2018_m_revue_belge_de_philologie_et_d'histoire_1922- for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_iii/1_1867_m_grammatici_graeci_recogniti_et_apparatu_critico_instructi_leipzig_q2079_1867-1910 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_iv/3_1891_m_commentaria_in_aristotelem_graeca_berlin_q64_1882- for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_8_1717_m_bibliotheca_graeca_sive_notitia_scriptorum_veterum_graecorum_hamburg_q1055_1705-1728 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_i_1572_m_thesaurus_græcae_linguae_genève_q71_1572 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1_1972_m_gli_incunaboli_dell'ambrosiana_vicenza_q6537_1972 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_s5-xxix/3_1974_m_the_library_1889- for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_lxxxi-lxxxii_1954-1955_m_archivio_storico_lombardo_1874- for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1_1923_m_les_filigranes_dictionnaire_historique_des_marques_du_papier_dès_leur_leipzig_q2079_1923 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_2_1923_m_les_filigranes_dictionnaire_historique_des_marques_du_papier_dès_leur_leipzig_q2079_1923 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_3_1923_m_les_filigranes_dictionnaire_historique_des_marques_du_papier_dès_leur_leipzig_q2079_1923 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_4_1923_m_les_filigranes_dictionnaire_historique_des_marques_du_papier_dès_leur_leipzig_q2079_1923 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_116/1-3_2014_m_la_bibliofilía_1899- for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_2_1894_m_studi_italiani_di_filologia_classica_1893- for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_3_1821_m_anecdota_graeca_berlin_q64_1814-1821 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_2_1816_m_anecdota_graeca_berlin_q64_1814-1821 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1_1814_m_anecdota_graeca_berlin_q64_1814-1821 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/iii_1901_m_grammatici_graeci_recogniti_et_apparatu_critico_instructi_leipzig_q2079_1867-1910 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_3/i_1867_m_grammatici_graeci_recogniti_et_apparatu_critico_instructi_leipzig_q2079_1867-1910 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_3/1_1899_m_sammlung_der_griechischen_dialekt-inschriften_göttingen_q3033_1884-1910 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_3/1_1899_m_sammlung_der_griechischen_dialekt-inschriften_göttingen_q3033_1884-1910 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_2/5_1823_m_poetae_minores_graeci_leipzig_q2079_1823 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1823_m_poetae_minores_graeci_leipzig_q2079_1823 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1823_m_poetae_minores_graeci_leipzig_q2079_1823 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1823_m_poetae_minores_graeci_leipzig_q2079_1823 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_3/5_1823_m_poetae_minores_graeci_leipzig_q2079_1823 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_4/5_1823_m_poetae_minores_graeci_leipzig_q2079_1823 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_5/5_1823_m_poetae_minores_graeci_leipzig_q2079_1823 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/6_1943_m_indice_generale_degli_incunaboli_delle_biblioteche_d'italia_roma_q220_1943-1981 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_2/6_1948_m_indice_generale_degli_incunaboli_delle_biblioteche_d'italia_roma_q220_1943-1981 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_3/6_1944_m_indice_generale_degli_incunaboli_delle_biblioteche_d'italia_roma_q220_1943-1981 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_4/6_1965_m_indice_generale_degli_incunaboli_delle_biblioteche_d'italia_roma_q220_1943-1981 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_5/6_1972_m_indice_generale_degli_incunaboli_delle_biblioteche_d'italia_roma_q220_1943-1981 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_6/6_1981_m_indice_generale_degli_incunaboli_delle_biblioteche_d'italia_roma_q220_1943-1981 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/5_1495_m_aristotelis_opera_[greek]_venezia_q641_1495-1498 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/2_1990_m_filigrane_di_cartiere_bresciane_brescia_q6221_1990-1991 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_2/2_1991_m_filigrane_di_cartiere_bresciane_brescia_q6221_1990-1991 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_1/2_1513_m_logoi_toutoni_ton_retoron_aiskinou_lysiou_alkidamantos_orationes_horum_venezia_q641_1513 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_2/2_1513_m_logoi_toutoni_ton_retoron_aiskinou_lysiou_alkidamantos_orationes_horum_venezia_q641_1513 for hypotheses...
#   - Processing 'MANIFESTATION_VOLUME_ID' for mentions...
#   - Creating new column 'MANIFESTATION_VOLUME_MENTIONING'.
#   - Creating new column 'MANIFESTATION_VOLUME_MENTIONED_BY'.
#   - Creating new column 'MANIFESTATION_MENTIONING'.
#   - Creating new column 'MANIFESTATION_MENTIONED_BY'.
#   - Creating new column 'MANIFESTATION_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'ITEM_ID' in sheet 'ITEM'...
#   - Writing cleaned data back to column 'OWNER_OF_ITEM_ID' in sheet 'ITEM'...
#   - Writing cleaned data back to column 'MANIFESTATION_VOLUME_ID' in sheet 'ITEM'...
#   - Writing cleaned data back to column 'MANIFESTATION_ID' in sheet 'ITEM'...
#   - Writing cleaned data back to column 'PHYSICAL_OBJECT_ID' in sheet 'ITEM'...
#   - Found primary ID column for linking: 'ITEM_ID'
#   - Updating sheet 'ITEM' with links...
#   - Creating new column 'ITEM_MENTIONING'.
#   - Creating new column 'ITEM_MENTIONED_BY'.
#   - Creating new column 'ITEM_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'PLACE'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_PLACE' in sheet 'PLACE'...
#   - Found primary ID column for linking: 'PLACE_ID'
#   - Updating sheet 'PLACE' with links...
#   - Creating new column 'PLACE_MENTIONING'.
#   - Creating new column 'PLACE_MENTIONED_BY'.
#   - Creating new column 'PLACE_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'ITEM_ID' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'PHYSICAL_OBJECT_ID_PAGE' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'MANIFESTATION_ID' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'PAGE_ID' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'DIGITAL_ITEM_ID_PAGE' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'PHYSICAL_OBJECT_ID' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'VISUAL_OBJECT_ID' in sheet 'PAGE'...
#   - Found primary ID column for linking: 'PAGE_ID'
#   - Updating sheet 'PAGE' with links...
#   - Creating new column 'PAGE_MENTIONING'.
#   - Creating new column 'PAGE_MENTIONED_BY'.
#   - Creating new column 'PAGE_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'VISUAL_OBJECT_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'VO_ID_TEXT_REFERRED_TO' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'OWNERSHIP_OF_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'INSCRIBER_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'SENDER_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'RECIPIENT_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Found primary ID column for linking: 'VISUAL_OBJECT_ID'
#   - Updating sheet 'VISUAL_OBJECT' with links...
#   - Creating new column 'VISUAL_OBJECT_MENTIONING'.
#   - Creating new column 'VISUAL_OBJECT_MENTIONED_BY'.
#   - Creating new column 'VISUAL_OBJECT_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'PERSON_ID' in sheet 'PERSON'...
#   - Writing cleaned data back to column 'INSTITUTION_ID_OF_PERSON' in sheet 'PERSON'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_PERSON' in sheet 'PERSON'...
#   - Found primary ID column for linking: 'PERSON_ID'
#   - Updating sheet 'PERSON' with links...
#   - Creating new column 'PERSON_MENTIONING'.
#   - Creating new column 'PERSON_MENTIONED_BY'.
#   - Creating new column 'PERSON_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Writing cleaned data back to column 'OWNERSHIP_OF_PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Writing cleaned data back to column 'CREATOR_OF_PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Found primary ID column for linking: 'PHYSICAL_OBJECT_ID'
#   - Updating sheet 'PHYSICAL_OBJECT' with links...
#   - Creating new column 'PHYSICAL_OBJECT_MENTIONING'.
#   - Creating new column 'PHYSICAL_OBJECT_MENTIONED_BY'.
#   - Creating new column 'PHYSICAL_OBJECT_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'EVENT_ID' in sheet 'EVENT'...
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'EVENT'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_EVENT' in sheet 'EVENT'...
#   - Found primary ID column for linking: 'EVENT_ID'
#   - Updating sheet 'EVENT' with links...
#   - Creating new column 'EVENT_MENTIONING'.
#   - Creating new column 'EVENT_MENTIONED_BY'.
#   - Creating new column 'EVENT_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'ABSTRACT_CHARACTER_ID' in sheet 'ABSTRACT_CHARACTER'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_ABSTRACT_CHARACTER' in sheet 'ABSTRACT_CHARACTER'...
#   - Found primary ID column for linking: 'ABSTRACT_CHARACTER_ID'
#   - Updating sheet 'ABSTRACT_CHARACTER' with links...
#   - Creating new column 'ABSTRACT_CHARACTER_MENTIONING'.
#   - Creating new column 'ABSTRACT_CHARACTER_MENTIONED_BY'.
#   - Creating new column 'ABSTRACT_CHARACTER_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'INSTITUTION_ID' in sheet 'INSTITUTION'...
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'INSTITUTION'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_INSTITUTION' in sheet 'INSTITUTION'...
#   - Found primary ID column for linking: 'INSTITUTION_ID'
#   - Updating sheet 'INSTITUTION' with links...
#   - Creating new column 'INSTITUTION_MENTIONING'.
#   - Creating new column 'INSTITUTION_MENTIONED_BY'.
#   - Creating new column 'INSTITUTION_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'MENTIONING_ID' in sheet 'MENTIONS'...
#   - Writing cleaned data back to column 'MENTIONED_ID' in sheet 'MENTIONS'...
#   - Skipping sheet 'MENTIONS': No column found starting with 'MENTIONS_ID'.
#   - Writing cleaned data back to column 'PERSON_CHARACTER_ID_A' in sheet 'RELATIONSHIP'...
#   - Writing cleaned data back to column 'RELATIONSHIP' in sheet 'RELATIONSHIP'...
#   - Writing cleaned data back to column 'PERSON_CHARACTER_ID_B' in sheet 'RELATIONSHIP'...
#   - Writing cleaned data back to column 'RELATION_ID' in sheet 'RELATIONSHIP'...
#   - Skipping sheet 'RELATIONSHIP': No column found starting with 'RELATIONSHIP_ID'.
#   - Writing cleaned data back to column 'HYPOTHESIS_ID' in sheet 'HYPOTHESIS'...
#   - Writing cleaned data back to column 'PERSON_ID_HYPOTHESIS_OF' in sheet 'HYPOTHESIS'...
#   - Writing cleaned data back to column 'HYPOTHESIS_ABOUT_ID(S)' in sheet 'HYPOTHESIS'...
#   - Found primary ID column for linking: 'HYPOTHESIS_ID'
#   - Updating sheet 'HYPOTHESIS' with links...
#   - Creating new column 'HYPOTHESIS_MENTIONING'.
#   - Creating new column 'HYPOTHESIS_MENTIONED_BY'.
# Successfully saved updates to BA-EG.xlsx
#
# Processing BPC-AB.xlsx...
#   - Cleaning column 'WORK_ID' in sheet 'WORK'...
#   - Cleaning column 'AUTHOR_WORK_ID' in sheet 'WORK'...
#   - Cleaning column 'EXPRESSION_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'WORK_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'TRANSLATOR_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'EDITOR_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'SCRIPTWRITER_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'COMPOSITOR_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'REVIEWER_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'OTHER_SECONDARY_ROLE_ID' in sheet 'EXPRESSION'...
#   - Cleaning column 'MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'MANIFESTATION_VOLUME_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'PLACE_OF_PUBLICATION_MANIFESTATION' in sheet 'MANIFESTATION'...
#   - Cleaning column 'EXPRESSION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'PUBLISHER_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'EDITOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'CORRECTOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'SPONSOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Cleaning column 'ITEM_ID' in sheet 'ITEM'...
#   - Cleaning column 'OWNER_OF_ITEM_ID' in sheet 'ITEM'...
#   - Cleaning column 'MANIFESTATION_VOLUME_ID' in sheet 'ITEM'...
#   - Cleaning column 'MANIFESTATION_ID' in sheet 'ITEM'...
#   - Cleaning column 'PHYSICAL_OBJECT_ID' in sheet 'ITEM'...
#   - Cleaning column 'PLACE_ID' in sheet 'PLACE'...
#   - Cleaning column 'WIKIDATA_ID_PLACE' in sheet 'PLACE'...
#   - Cleaning column 'ITEM_ID' in sheet 'PAGE'...
#   - Cleaning column 'PHYSICAL_OBJECT_ID_PAGE' in sheet 'PAGE'...
#   - Cleaning column 'MANIFESTATION_ID' in sheet 'PAGE'...
#   - Cleaning column 'PAGE_ID' in sheet 'PAGE'...
#   - Cleaning column 'DIGITAL_ITEM_ID_PAGE' in sheet 'PAGE'...
#   - Cleaning column 'PHYSICAL_OBJECT_ID' in sheet 'PAGE'...
#   - Cleaning column 'VISUAL_OBJECT_ID' in sheet 'PAGE'...
#   - Cleaning column 'VISUAL_OBJECT_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'VO_ID_TEXT_REFERRED_TO' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'PLACE_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'OWNERSHIP_OF_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'INSCRIBER_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'SENDER_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'RECIPIENT_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Cleaning column 'PERSON_ID' in sheet 'PERSON'...
#   - Cleaning column 'INSTITUTION_ID_OF_PERSON' in sheet 'PERSON'...
#   - Cleaning column 'WIKIDATA_ID_PERSON' in sheet 'PERSON'...
#   - Cleaning column 'MENTIONING_ID' in sheet 'MENTIONS'...
#   - Cleaning column 'MENTIONED_ID' in sheet 'MENTIONS'...
#   - Cleaning column 'HYPOTHESIS_ID' in sheet 'HYPOTHESIS'...
#   - Cleaning column 'PERSON_ID_HYPOTHESIS_OF' in sheet 'HYPOTHESIS'...
#   - Cleaning column 'HYPOTHESIS_ABOUT_ID(S)' in sheet 'HYPOTHESIS'...
#   - Cleaning column 'PERSON_CHARACTER_ID_A' in sheet 'RELATIONSHIP'...
#   - Cleaning column 'PERSON_CHARACTER_ID_B' in sheet 'RELATIONSHIP'...
#   - Cleaning column 'RELATION_ID' in sheet 'RELATIONSHIP'...
#   - Cleaning column 'RELATIONSHIP' in sheet 'RELATIONSHIP'...
#   - Cleaning column 'PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Cleaning column 'PLACE_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Cleaning column 'OWNERSHIP_OF_PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Cleaning column 'CREATOR_OF_PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Cleaning column 'EVENT_ID' in sheet 'EVENT'...
#   - Cleaning column 'PLACE_ID' in sheet 'EVENT'...
#   - Cleaning column 'WIKIDATA_ID_EVENT' in sheet 'EVENT'...
#   - Cleaning column 'ABSTRACT_CHARACTER_ID' in sheet 'ABSTRACT_CHARACTER'...
#   - Cleaning column 'WIKIDATA_ID_ABSTRACT_CHARACTER' in sheet 'ABSTRACT_CHARACTER'...
#   - Cleaning column 'INSTITUTION_ID' in sheet 'INSTITUTION'...
#   - Cleaning column 'PLACE_ID' in sheet 'INSTITUTION'...
#   - Cleaning column 'WIKIDATA_ID_INSTITUTION' in sheet 'INSTITUTION'...
#   - Writing cleaned data back to column 'WORK_ID' in sheet 'WORK'...
#   - Writing cleaned data back to column 'AUTHOR_WORK_ID' in sheet 'WORK'...
#   - Found primary ID column for linking: 'WORK_ID'
#   - Updating sheet 'WORK' with links...
#   - Creating new column 'WORK_MENTIONING'.
#   - Creating new column 'WORK_MENTIONED_BY'.
#   - Creating new column 'WORK_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'EXPRESSION_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'WORK_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'TRANSLATOR_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'EDITOR_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'SCRIPTWRITER_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'COMPOSITOR_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'REVIEWER_ID' in sheet 'EXPRESSION'...
#   - Writing cleaned data back to column 'OTHER_SECONDARY_ROLE_ID' in sheet 'EXPRESSION'...
#   - Found primary ID column for linking: 'EXPRESSION_ID'
#   - Updating sheet 'EXPRESSION' with links...
#   - Creating new column 'EXPRESSION_MENTIONING'.
#   - Creating new column 'EXPRESSION_MENTIONED_BY'.
#   - Creating new column 'EXPRESSION_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'MANIFESTATION_VOLUME_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'EXTERNAL_ID_MANIFESTATION' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'PLACE_OF_PUBLICATION_MANIFESTATION' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'EXPRESSION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'PUBLISHER_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'EDITOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'CORRECTOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Writing cleaned data back to column 'SPONSOR_MANIFESTATION_ID' in sheet 'MANIFESTATION'...
#   - Found primary ID column for linking: 'MANIFESTATION_ID'
#   - Updating sheet 'MANIFESTATION' with links...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_id_l'abbé_frémont,_1852-1912._pour_servir_à_l'histoire_religieuse_siegfried_agnès_paris_q90_1932_1 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_id_l'abbé_frémont,_1852-1912._pour_servir_à_l'histoire_religieuse_siegfried_agnès_paris_q90_1932_2 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_id_journal_claudel_paul_paris_q90_1968-1969_1 for hypotheses...
#     - Also checking 'MANIFESTATION_VOLUME_ID': m_vol_id_journal_claudel_paul_paris_q90_1968-1969_2 for hypotheses...
#   - Processing 'MANIFESTATION_VOLUME_ID' for mentions...
#   - Creating new column 'MANIFESTATION_VOLUME_MENTIONING'.
#   - Creating new column 'MANIFESTATION_VOLUME_MENTIONED_BY'.
#   - Creating new column 'MANIFESTATION_MENTIONING'.
#   - Creating new column 'MANIFESTATION_MENTIONED_BY'.
#   - Creating new column 'MANIFESTATION_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'ITEM_ID' in sheet 'ITEM'...
#   - Writing cleaned data back to column 'OWNER_OF_ITEM_ID' in sheet 'ITEM'...
#   - Writing cleaned data back to column 'MANIFESTATION_VOLUME_ID' in sheet 'ITEM'...
#   - Writing cleaned data back to column 'MANIFESTATION_ID' in sheet 'ITEM'...
#   - Writing cleaned data back to column 'PHYSICAL_OBJECT_ID' in sheet 'ITEM'...
#   - Found primary ID column for linking: 'ITEM_ID'
#   - Updating sheet 'ITEM' with links...
#   - Creating new column 'ITEM_MENTIONING'.
#   - Creating new column 'ITEM_MENTIONED_BY'.
#   - Creating new column 'ITEM_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'PLACE'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_PLACE' in sheet 'PLACE'...
#   - Found primary ID column for linking: 'PLACE_ID'
#   - Updating sheet 'PLACE' with links...
#   - Creating new column 'PLACE_MENTIONING'.
#   - Creating new column 'PLACE_MENTIONED_BY'.
#   - Creating new column 'PLACE_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'ITEM_ID' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'PHYSICAL_OBJECT_ID_PAGE' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'MANIFESTATION_ID' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'PAGE_ID' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'DIGITAL_ITEM_ID_PAGE' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'PHYSICAL_OBJECT_ID' in sheet 'PAGE'...
#   - Writing cleaned data back to column 'VISUAL_OBJECT_ID' in sheet 'PAGE'...
#   - Found primary ID column for linking: 'PAGE_ID'
#   - Updating sheet 'PAGE' with links...
#   - Creating new column 'PAGE_MENTIONING'.
#   - Creating new column 'PAGE_MENTIONED_BY'.
#   - Creating new column 'PAGE_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'VISUAL_OBJECT_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'VO_ID_TEXT_REFERRED_TO' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'OWNERSHIP_OF_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'INSCRIBER_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'SENDER_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Writing cleaned data back to column 'RECIPIENT_VISUAL_ID' in sheet 'VISUAL_OBJECT'...
#   - Found primary ID column for linking: 'VISUAL_OBJECT_ID'
#   - Updating sheet 'VISUAL_OBJECT' with links...
#   - Creating new column 'VISUAL_OBJECT_MENTIONING'.
#   - Creating new column 'VISUAL_OBJECT_MENTIONED_BY'.
#   - Creating new column 'VISUAL_OBJECT_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'PERSON_ID' in sheet 'PERSON'...
#   - Writing cleaned data back to column 'INSTITUTION_ID_OF_PERSON' in sheet 'PERSON'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_PERSON' in sheet 'PERSON'...
#   - Found primary ID column for linking: 'PERSON_ID'
#   - Updating sheet 'PERSON' with links...
#   - Creating new column 'PERSON_MENTIONING'.
#   - Creating new column 'PERSON_MENTIONED_BY'.
#   - Creating new column 'PERSON_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'MENTIONING_ID' in sheet 'MENTIONS'...
#   - Writing cleaned data back to column 'MENTIONED_ID' in sheet 'MENTIONS'...
#   - Skipping sheet 'MENTIONS': No column found starting with 'MENTIONS_ID'.
#   - Writing cleaned data back to column 'HYPOTHESIS_ID' in sheet 'HYPOTHESIS'...
#   - Writing cleaned data back to column 'PERSON_ID_HYPOTHESIS_OF' in sheet 'HYPOTHESIS'...
#   - Writing cleaned data back to column 'HYPOTHESIS_ABOUT_ID(S)' in sheet 'HYPOTHESIS'...
#   - Found primary ID column for linking: 'HYPOTHESIS_ID'
#   - Updating sheet 'HYPOTHESIS' with links...
#   - Creating new column 'HYPOTHESIS_MENTIONING'.
#   - Creating new column 'HYPOTHESIS_MENTIONED_BY'.
#   - Writing cleaned data back to column 'PERSON_CHARACTER_ID_A' in sheet 'RELATIONSHIP'...
#   - Writing cleaned data back to column 'RELATIONSHIP' in sheet 'RELATIONSHIP'...
#   - Writing cleaned data back to column 'PERSON_CHARACTER_ID_B' in sheet 'RELATIONSHIP'...
#   - Writing cleaned data back to column 'RELATION_ID' in sheet 'RELATIONSHIP'...
#   - Skipping sheet 'RELATIONSHIP': No column found starting with 'RELATIONSHIP_ID'.
#   - Writing cleaned data back to column 'PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Writing cleaned data back to column 'OWNERSHIP_OF_PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Writing cleaned data back to column 'CREATOR_OF_PHYSICAL_OBJECT_ID' in sheet 'PHYSICAL_OBJECT'...
#   - Found primary ID column for linking: 'PHYSICAL_OBJECT_ID'
#   - Updating sheet 'PHYSICAL_OBJECT' with links...
#   - Creating new column 'PHYSICAL_OBJECT_MENTIONING'.
#   - Creating new column 'PHYSICAL_OBJECT_MENTIONED_BY'.
#   - Creating new column 'PHYSICAL_OBJECT_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'EVENT_ID' in sheet 'EVENT'...
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'EVENT'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_EVENT' in sheet 'EVENT'...
#   - Found primary ID column for linking: 'EVENT_ID'
#   - Updating sheet 'EVENT' with links...
#   - Creating new column 'EVENT_MENTIONING'.
#   - Creating new column 'EVENT_MENTIONED_BY'.
#   - Creating new column 'EVENT_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'ABSTRACT_CHARACTER_ID' in sheet 'ABSTRACT_CHARACTER'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_ABSTRACT_CHARACTER' in sheet 'ABSTRACT_CHARACTER'...
#   - Found primary ID column for linking: 'ABSTRACT_CHARACTER_ID'
#   - Updating sheet 'ABSTRACT_CHARACTER' with links...
#   - Creating new column 'ABSTRACT_CHARACTER_MENTIONING'.
#   - Creating new column 'ABSTRACT_CHARACTER_MENTIONED_BY'.
#   - Creating new column 'ABSTRACT_CHARACTER_HYPOTHESIS_ID'.
#   - Writing cleaned data back to column 'INSTITUTION_ID' in sheet 'INSTITUTION'...
#   - Writing cleaned data back to column 'PLACE_ID' in sheet 'INSTITUTION'...
#   - Writing cleaned data back to column 'WIKIDATA_ID_INSTITUTION' in sheet 'INSTITUTION'...
#   - Found primary ID column for linking: 'INSTITUTION_ID'
#   - Updating sheet 'INSTITUTION' with links...
#   - Creating new column 'INSTITUTION_MENTIONING'.
#   - Creating new column 'INSTITUTION_MENTIONED_BY'.
#   - Creating new column 'INSTITUTION_HYPOTHESIS_ID'.
# Successfully saved updates to BPC-AB.xlsx
#
# Processing columns_trace.xlsx...
#   - Cleaning column 'WORK_ID' in sheet 'FINAL'...
#   - Cleaning column 'AUTHOR_WORK_ID' in sheet 'FINAL'...
#   - Cleaning column 'WORK_ID' in sheet 'Copy of Sheet1'...
#   - Cleaning column 'PERSON_ID_AUTHOR_WORK' in sheet 'Copy of Sheet1'...
#   - Cleaning column 'INSTITUTION_ID_AUTHOR_WORK' in sheet 'Copy of Sheet1'...
#   - Writing cleaned data back to column 'WORK_ID' in sheet 'FINAL'...
#   - Writing cleaned data back to column 'AUTHOR_WORK_ID' in sheet 'FINAL'...
#   - Skipping sheet 'FINAL': No column found starting with 'FINAL_ID'.
#   - Writing cleaned data back to column 'WORK_ID' in sheet 'Copy of Sheet1'...
#   - Writing cleaned data back to column 'PERSON_ID_AUTHOR_WORK' in sheet 'Copy of Sheet1'...
#   - Writing cleaned data back to column 'INSTITUTION_ID_AUTHOR_WORK' in sheet 'Copy of Sheet1'...
#   - Skipping sheet 'Copy of Sheet1': No column found starting with 'Copy of Sheet1_ID'.
# Skipping save for 'columns_trace.xlsx' as per exclusion rules.
